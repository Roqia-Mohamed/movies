# %%
import pandas as pd

# %%
import numpy as np

# %%
x=pd.read_csv("project films.csv")
x
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
x.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
x.release_date
# Out:
# 0          6/9/2015
# 1         5/13/2015
# 2         3/18/2015
# 3        12/15/2015
# 4          4/1/2015
#             ...
# 10861     6/15/1966
# 10862    12/21/1966
# 10863      1/1/1966
# 10864     11/2/1966
# 10865    11/15/1966
# Name: release_date, Length: 10866, dtype: object

# %%
x['release_date'] = pd.to_datetime(x['release_date'])
x
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
x.dtypes
# Out:
# id                               int64
# imdb_id                         object
# popularity                     float64
# budget                           int64
# revenue                          int64
# original_title                  object
# cast                            object
# homepage                        object
# director                        object
# tagline                         object
# keywords                        object
# overview                        object
# runtime                          int64
# genres                          object
# production_companies            object
# release_date            datetime64[ns]
# vote_count                       int64
# vote_average                   float64
# release_year            datetime64[ns]
# budget_adj                     float64
# revenue_adj                    float64
# dtype: object

# %%
x.isnull().sum()
x.head()
x.isnull().sum()
x.dropna(inplace=True)
x.isnull().sum()
x.dropna(how='any',subset=['genres','director'],inplace=True)
x.isnull().sum()
x
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10724     668  tt0064757    1.778746    7000000    81974493
# 10759     948  tt0077651    1.198849     300000    70000000
# 10760    8469  tt0077975    1.157930    2700000   141000000
# 10817   13963  tt0077838    0.064029          0      321952
# 10819   16214  tt0077696    0.044675          0    78000000
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...

# %%
x['month'] = x['release_date'].dt.month
x
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10724     668  tt0064757    1.778746    7000000    81974493
# 10759     948  tt0077651    1.198849     300000    70000000
# 10760    8469  tt0077975    1.157930    2700000   141000000
# 10817   13963  tt0077838    0.064029          0      321952
# 10819   16214  tt0077696    0.044675          0    78000000
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...

# %%
x['release_date'] = pd.to_datetime(x['release_date'], format='%m/%d/%y') 

# extract the day, month, and year components
x['day'] = x['release_date'].dt.day
x['month'] =x['release_date'].dt.month
x['year'] = x['release_date'].dt.year
x

# show the modified data frame
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10724     668  tt0064757    1.778746    7000000    81974493
# 10759     948  tt0077651    1.198849     300000    70000000
# 10760    8469  tt0077975    1.157930    2700000   141000000
# 10817   13963  tt0077838    0.064029          0      321952
# 10819   16214  tt0077696    0.044675          0    78000000
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...

# %%
xx = x.drop(columns=['release_year', 'release_date', 'day'])
xx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 xx = x.drop(columns=['release_year', 'release_date', 'day'])
#       2 xx
#
# NameError: name 'x' is not defined

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(x['original_title'], x['runtime'], color='skyblue')  # Create a bar plot

# Add title and labels
plt.title('Runtime of Movies')
plt.xlabel('Original Title')
plt.ylabel('Runtime (minutes)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

top_10_movies = x.sort_values(by='runtime', ascending=False).head(10)


# Create a bar plot for the top 10 movies
plt.figure(figsize=(12, 8))  # Set the figure size
plt.bar(top_10_movies['original_title'], top_10_movies['runtime'], color='skyblue')  # Create a bar plot

# Add title and labels
plt.title('Top 10 Movies by Runtime')
plt.xlabel('Original Title')
plt.ylabel('Runtime (minutes)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))  # Set the figure size
plt.scatter(x['runtime'], x['vote_average'], color='blue', alpha=0.7)  # Create a scatter plot

# Add title and labels
plt.title('Relationship between Runtime and Vote Average')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Vote Average')

# Show the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
